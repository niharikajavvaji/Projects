# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import mutual_info_regression
from sklearn.feature_selection import SelectPercentile
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.model_selection import cross_val_score

# %%
student=pd.read_csv("Student_Performance.csv")

# %%
student.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
student.shape
# Out:
# (10000, 6)

# %%
student.isna().sum()
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
student['Performance Index'].min()
# Out:
# 10.0

# %%
student['Performance Index'].max()
# Out:
# 100.0

# %%
student.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  object
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 468.9+ KB

# %%
student['Extracurricular Activities']=np.where(student['Extracurricular Activities'] == "Yes",1,0)

# %%
student.head()
# Out:
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0              7               99                           1            9
# 1              4               82                           0            4
# 2              8               51                           1            7
# 3              5               52                           1            5
# 4              7               75                           0            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
 student.corr()
# Out:
#                                   Hours Studied  Previous Scores  \
# Hours Studied                          1.000000        -0.012390
# Previous Scores                       -0.012390         1.000000
# Extracurricular Activities             0.003873         0.008369
# Sleep Hours                            0.001245         0.005944
# Sample Question Papers Practiced       0.017463         0.007888
# Performance Index                      0.373730         0.915189
#
#                                   Extracurricular Activities  Sleep Hours  \
# Hours Studied                                       0.003873     0.001245
# Previous Scores                                     0.008369     0.005944
# Extracurricular Activities                          1.000000    -0.023284
# Sleep Hours                                        -0.023284     1.000000
# Sample Question Papers Practiced                    0.013103     0.003990
# ...

# %%
sns.heatmap(student.corr(),annot=True,cmap='viridis')
plt.show()

# %%
x_train,x_test,y_train,y_test=train_test_split(student.drop(labels=['Performance Index'],axis=1),
                                               student['Performance Index'],
                                               test_size=0.3,
                                               random_state=0)

# %%
x_train.head()
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 7681              9               60                           0            4
# 9031              8               43                           0            5
# 3691              5               74                           1            4
# 202               9               52                           0            5
# 5625              8               57                           0            5
#
#       Sample Question Papers Practiced
# 7681                                 5
# 9031                                 5
# 3691                                 6
# 202                                  9
# 5625                                 4

# %%
mutual_info=mutual_info_regression(x_train,y_train)
mutual_info
# Out:
# array([0.13820293, 0.94987729, 0.        , 0.00522418, 0.        ])

# %%
mutual_info=pd.Series(mutual_info)
mutual_info.index=x_train.columns
mutual_info.sort_values(ascending=False)
# Out:
# Previous Scores                     0.949877
# Hours Studied                       0.138203
# Sleep Hours                         0.005224
# Extracurricular Activities          0.000000
# Sample Question Papers Practiced    0.000000
# dtype: float64

# %%
mutual_info.sort_values(ascending=False).plot.bar(figsize=(15,5))
# Out:
# <Axes: >

# %%
selected_top_performances=SelectPercentile(mutual_info_regression,percentile=40)
selected_top_performances.fit(x_train,y_train)
# Out:
# SelectPercentile(percentile=40,
#                  score_func=<function mutual_info_regression at 0x00000196990A9EE0>)

# %%
selected_top_performances.get_support()
# Out:
# array([ True,  True, False, False, False])

# %%
x_train.columns[selected_top_performances.get_support()]
# Out:
# Index(['Hours Studied', 'Previous Scores'], dtype='object')

# %%
x_train.drop(['Sleep Hours','Extracurricular Activities','Sample Question Papers Practiced'],inplace=True,axis=1)

# %%
x_train.head()
# Out:
#       Hours Studied  Previous Scores
# 7681              9               60
# 9031              8               43
# 3691              5               74
# 202               9               52
# 5625              8               57

# %%
x_test.drop(['Sleep Hours','Extracurricular Activities','Sample Question Papers Practiced'],inplace=True,axis=1)

# %%
x_test.head()
# Out:
#       Hours Studied  Previous Scores
# 9394              4               67
# 898               8               60
# 2398              6               90
# 5906              1               51
# 2343              2               90

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_preds=model.predict(x_train)

# %%
mean_squared_error(y_train, y_preds)
# Out:
# 5.222394440143651

# %%
rmse=np.sqrt(mean_squared_error(y_train, y_preds))
rmse
# Out:
# np.float64(2.285255880671495)

# %%
r2_score(y_train, y_preds)
# Out:
# 0.9859839329269132

# %%
y_predicts=model.predict(x_test)

# %%
mean_squared_error(y_test,y_predicts)
# Out:
# 5.197114973058084

# %%
rmse1=np.sqrt(mean_squared_error(y_test, y_predicts))
rmse1
# Out:
# np.float64(2.2797181784286593)

# %%
r2 = r2_score(y_test, y_predicts)
r2
# Out:
# 0.9855989148980643

# %%
scores = cross_val_score(model, x_train, y_train, cv=5, scoring='r2')

# %%
print(scores)
print(scores.mean())
# Out:
# [0.98630254 0.98501044 0.98627317 0.98674702 0.98542013]
# 0.9859506603227279

# %%
import matplotlib.pyplot as plt

residuals = y_test - model.predict(x_test)

plt.scatter(model.predict(x_test), residuals)
plt.xlabel("Predicted")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()

# %%
import pandas as pd

coefficients = pd.DataFrame({
    "Feature": x_train.columns,
    "Coefficient": model.coef_
})

print(coefficients.sort_values(by="Coefficient", ascending=False))
# Out:
#            Feature  Coefficient
# 0    Hours Studied     2.854335
# 1  Previous Scores     1.020346
