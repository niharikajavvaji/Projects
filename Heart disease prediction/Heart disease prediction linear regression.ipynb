# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix,classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# %%
heartdisease_data=pd.read_csv("Heart disease prediction.csv")

# %%
heartdisease_data.shape
# Out:
# (12000, 28)

# %%
heartdisease_data.drop(['Gender','ECG_Result','Smoking_Status','Physical_Activity_Level','Risk_Level'],axis=1,inplace=True)

# %%
heartdisease_data.head()
# Out:
#    Age  Gender_M  Gender_F  Resting_BP  Cholesterol  Fasting_Blood_Sugar  \
# 0   62         1         0         100          166                   84
# 1   52         0         1         107          214                   71
# 2   64         1         0         137          184                   70
# 3   77         1         0         152          142                   92
# 4   51         0         1         119          174                  161
#
#    Max_Heart_Rate  ECG_Result_N  ECG_Result_S  ECG_Result_L  ...  \
# 0             164             1             0             0  ...
# 1             173             1             0             0  ...
# 2             159             1             0             0  ...
# 3             157             0             1             0  ...
# 4             171             0             1             0  ...
#
#    Physical_Activity_Level_E  Diet_Quality_Score  Sleep_Hours  BMI  Diabetes  \
# ...

# %%
corr_matrix=heartdisease_data.corr()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(corr_matrix,annot=True,cmap='viridis',fmt=".2f",linewidth=.5)
plt.title("Heart disease prediction")
plt.show()

# %%
x=heartdisease_data[['Age','Resting_BP','Cholesterol','Fasting_Blood_Sugar','Smoking_Status_C','Diabetes','Hypertension']]
plt.figure(figsize=(10,10))
sns.heatmap(x.corr(),annot=True,cmap='viridis',fmt=".2f",linewidth=.5)
plt.title("Heart disease prediction")
plt.show()

# %%
y=heartdisease_data['Risk_Score']

# %%
y.head()
# Out:
# 0    28.09
# 1    16.27
# 2    43.55
# 3    50.84
# 4    40.87
# Name: Risk_Score, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()
x_train_scaled=scaler.fit_transform(x_train)
x_test_scaled=scaler.fit_transform(x_test)

# %%
y_test.head()
# Out:
# 1935    13.65
# 6494    36.55
# 1720    43.37
# 9120     7.20
# 360     30.04
# Name: Risk_Score, dtype: float64

# %%
ridge_model=Ridge(alpha=0.00001,max_iter=10000)

# %%
ridge_model.fit(x_train_scaled,y_train)
# Out:
# Ridge(alpha=1e-05, max_iter=10000)

# %%
y_ridge_predict=ridge_model.predict(x_test_scaled)

# %%
from sklearn.metrics import mean_squared_error
mse1=mean_squared_error(y_true=y_test,y_pred=y_ridge_predict)
print(mse1)
# Out:
# 28.380437516147794

# %%
model.fit(x_train_scaled,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 model.fit(x_train_scaled,y_train)
#
# NameError: name 'model' is not defined

# %%
y_pred=model.predict(x_test_scaled)

# %%
from sklearn.metrics import mean_squared_error

msr=mean_squared_error(y_true=y_test,y_pred=y_pred)
print(msr)
# Out:
# 26.010140311300233

# %%
ridge_model.coef_
# Out:
# array([3.99787842, 1.98981547, 2.05614192, 1.34206713, 5.62824667,
#        4.13685879, 4.4978151 ])

# %%
lasso=Lasso(alpha=0.1)

# %%
lasso.fit(x_train_scaled,y_train)
# Out:
# Lasso(alpha=0.1)

# %%
lasso_predict=lasso.predict(x_test_scaled)

# %%
mse2=mean_squared_error(y_true=y_test,y_pred=lasso_predict)

# %%
mse2
# Out:
# 28.36875414581483

# %%
from sklearn.linear_model import LassoCV
alphas = np.logspace(-4, 1, 100)
model_cv = LassoCV(alphas=alphas, cv=5, max_iter=10000)

# %%
model_cv.fit(x_train_scaled,y_train)
# Out:
# LassoCV(alphas=array([1.00000000e-04, 1.12332403e-04, 1.26185688e-04, 1.41747416e-04,
#        1.59228279e-04, 1.78864953e-04, 2.00923300e-04, 2.25701972e-04,
#        2.53536449e-04, 2.84803587e-04, 3.19926714e-04, 3.59381366e-04,
#        4.03701726e-04, 4.53487851e-04, 5.09413801e-04, 5.72236766e-04,
#        6.42807312e-04, 7.22080902e-04, 8.11130831e-04, 9.11162756e-04,
#        1.02353102e-03, 1.14975700e-0...
#        6.89261210e-01, 7.74263683e-01, 8.69749003e-01, 9.77009957e-01,
#        1.09749877e+00, 1.23284674e+00, 1.38488637e+00, 1.55567614e+00,
#        1.74752840e+00, 1.96304065e+00, 2.20513074e+00, 2.47707636e+00,
#        2.78255940e+00, 3.12571585e+00, 3.51119173e+00, 3.94420606e+00,
#        4.43062146e+00, 4.97702356e+00, 5.59081018e+00, 6.28029144e+00,
#        7.05480231e+00, 7.92482898e+00, 8.90215085e+00, 1.00000000e+01]),
#         cv=5, max_iter=10000)

# %%
cv_predict=model_cv.predict(x_test_scaled)

# %%
mse4=mean_squared_error(y_true=y_test,y_pred=cv_predict)

# %%
mse4
# Out:
# 28.379711517403507
